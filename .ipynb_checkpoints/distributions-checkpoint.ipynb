# %% [markdown]
# # 1-D Exploratory Data Analysis
#
# In this notebook, do some EDA in one dimension. Pick a column  (or a set of columns) you're interested in looking at. Calculate some summary statistics (like mean,median,min,max,sd). Then, make some plots to visualize the distribution of the data. Distirbution plots include things like histograms, boxplots, dotplots, beeswarms, and violin plots. Review [ggplot-intro](https://github.com/data4news/ggplot-intro) for examples of these kinds of distribution plots.

# %% [markdown]
# ### Standard Python and R imports

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load the data

# %%
# Import data with Python
merged_data = pd.read_csv("merged_data.csv")
merged_data.head()
# Out:
#   Job.Number Borough.Name  Count.Permits First.Permit.Date Current.Date  \
# 0  120351662    Manhattan            0.0         5/13/2010    4/19/2025
# 1  120470409    Manhattan            0.0         9/16/2010    4/19/2025
# 2  120486633    Manhattan            0.0         9/29/2010    4/19/2025
# 3  120725705    Manhattan            0.0         6/16/2011    4/19/2025
# 4  120987236    Manhattan            0.0          3/1/2012    4/19/2025
#
#    Age..in.years. Permit.Expiration.Date  Sidewalk.Shed.Linear.Feet  \
# 0       14.942466              5/22/2025                       56.0
# 1       14.597260              6/17/2025                       65.0
# 2       14.561644              9/20/2025                      100.0
# 3       13.849315              3/11/2026                      314.0
# 4       13.139726              6/18/2025                       77.0
#
#   Construction.Material Current.Job.Status  BIN.Number  Community.Board  \
# 0                 STEEL                  R     1050240              108
# 1            STEEL/WOOD                  R     1017833              105
# 2        WOOD AND STEEL                  R     1079685              103
# 3          WOOD & STEEL                  R     1026319              104
# 4          WOOD & STEEL                  R     1083575              104
#
#    Latitude.Point  Longitude.Point House.Number       Street.Name  \
# 0        40.78184        -73.94844         1772          2 AVENUE
# 1        40.73590        -73.98799          116    EAST 17 STREET
# 2        40.72631        -73.97949          605  EAST    9 STREET
# 3        40.75827        -73.99532          443    WEST 40 STREET
# 4        40.74551        -74.00375          444  WEST   21 STREET
#
#    Borough.Digit  Block  Lot  Applicant.Business.Name  ProCert Source  \
# 0              1   1555    4           CS BRIDGE CORP        1    BIS
# 1              1    872   68  ROCKLEDGE SCAFFOLD CORP        1    BIS
# 2              1    392   10  ROCKLEDGE SCAFFOLD CORP        1    BIS
# 3              1   1050    6             BS GROUP INC        1    BIS
# 4              1    718    1     ARSENAL SCAFFOLD INC        1    BIS
#
#                       activity                   Commercial        GEOID  \
# 0  Construction or Maintenance  Commercial District/Overlay  36061015402
# 1  Construction or Maintenance       Other Zoning Districts  36061005000
# 2  Construction or Maintenance       Other Zoning Districts  36061002800
# 3  Construction or Maintenance  Commercial District/Overlay  36061011500
# 4  Construction or Maintenance       Other Zoning Districts  36061008900
#
#    STATE  COUNTY  TRACT  BLOCK  \
# 0     36      61  15402   3000
# 1     36      61   5000   2000
# 2     36      61   2800   3001
# 3     36      61  11500   2002
# 4     36      61   8900   4001
#
#                                              NAME  population_estimate  \
# 0  Census Tract 154.02, New York County, New York                 3579
# 1      Census Tract 50, New York County, New York                 5042
# 2      Census Tract 28, New York County, New York                 6483
# 3     Census Tract 115, New York County, New York                 3367
# 4      Census Tract 89, New York County, New York                 5844
#
#    black_african_estimate  occupied_estimate  vacant_estimate  \
# 0                     931               1681              427
# 1                      70               2852              622
# 2                    1146               3073              303
# 3                     409               1750              565
# 4                     306               3095              603
#
#    owner_occupied_estimate  renter_occupied_estimate  owner_income_estimate  \
# 0                      659                      1022               212008.0
# 1                     1424                      1428               195956.0
# 2                      482                      2591               156071.0
# 3                      239                      1511               217356.0
# 4                      974                      2121               158555.0
#
#    renter_income_estimate  population_moe  black_african_moe  occupied_moe  \
# 0                103182.0            1259               1007           314
# 1                138364.0             814                 74           299
# 2                 44028.0             901                639           306
# 3                134427.0             701                229           194
# 4                 88665.0             620                231           345
#
#    vacant_moe  owner_occupied_moe  renter_occupied_moe  owner_income_moe  \
# 0         227                 235                  206          127402.0
# 1         246                 309                  222           72736.0
# 2         168                 162                  321           73124.0
# 3         163                  89                  189           85738.0
# 4         206                 224                  344           23669.0
#
#    renter_income_moe
# 0            28807.0
# 1            33353.0
# 2            12781.0
# 3            48688.0
# 4            37651.0

# %%
sheds_by_census_tract = merged_data.pivot_table(
    index='GEOID',
    values='Job.Number',
    aggfunc='count') \
    .reset_index() \
    .rename(columns={'Job.Number': 'active_shed_licenses'})

sheds_by_census_tract
# Out:
#             GEOID  active_shed_licenses
# 0     36005000400                     1
# 1     36005001600                     3
# 2     36005001901                     3
# 3     36005001902                     8
# 4     36005001903                     1
# ...           ...                   ...
# 1533  36085027702                     1
# 1534  36085027706                     2
# 1535  36085027900                     1
# 1536  36085030302                     1
# 1537  36085031902                     5
#
# [1538 rows x 2 columns]

# %%
from dotenv import load_dotenv
load_dotenv() # <- searches for a file named .env and loads the environment variables in it
# Out:
# True

# %%
# %%R
#
# require('tidycensus')
#
# # because it an environment variable, we don't have to
# # explicitly pass this string to R, it is readable here
# # in this R cell.
# census_api_key(Sys.getenv("CENSUS_API_KEY"))
# Out:
# R[write to console]: Loading required package: tidycensus
#
# R[write to console]: To install your API key for use in future sessions, run this function with `install = TRUE`.

# %%
# %%R
# require("tigris")
# Out:
# R[write to console]: Loading required package: tigris
#
# R[write to console]: To enable caching of data, set `options(tigris_use_cache = TRUE)`
# in your R script or .Rprofile.

# %%
# %%R
#
# # long-form data: with only one numeric data
#
# # the variable B01003_001 was selectd from the census table
# # for population, which we found in censusreporter here:
# # https://censusreporter.org/tables/B01003/
#
#
# # Here are the various geographies you can use with tidycensus
# # https://walker-data.com/tidycensus/articles/basic-usage.html#geography-in-tidycensus
#
# # Get variable from ACS
# nyc_census_data <- get_acs(geography = "tract",
#                       state='NY',
#                       county = c("New York", "Kings", "Bronx", "Queens", "Richmond"),
#                       variables = c(
#                         population = "B01003_001",
#                         occupied = "B25002_002",
#                         vacant = "B25002_003",
#                         owner_occupied = "B25003_002",
#                         renter_occupied = "B25003_003",
#                         owner_income = "B25119_002",
#                         renter_income = "B25119_003"
#                       ),
#                       year = 2021,
#                       survey="acs5",
#                       geometry=F,
#                       cb = T)
#
# nyc_census_data <- nyc_census_data #%>%
#     #erase_water()
# Out:
# R[write to console]: Getting data from the 2017-2021 5-year ACS
#
# R[write to console]: Using FIPS code '36' for state 'NY'
#
# R[write to console]: Using FIPS code '061' for 'New York County'
#
# R[write to console]: Using FIPS code '047' for 'Kings County'
#
# R[write to console]: Using FIPS code '005' for 'Bronx County'
#
# R[write to console]: Using FIPS code '081' for 'Queens County'
#
# R[write to console]: Using FIPS code '085' for 'Richmond County'

# %%
# %%R
# nyc_census_data
#
# # pivot from wide to long
# nyc_census_data <- nyc_census_data %>%
#   pivot_wider(
#     names_from=variable,
#     values_from = c(estimate, moe),
#     names_glue = "{variable}_{.value}"
#   )
#
# nyc_census_data
# Out:
# # A tibble: 2,327 × 16
#    GEOID       NAME        population_estimate occupied_estimate vacant_estimate
#    <chr>       <chr>                     <dbl>             <dbl>           <dbl>
#  1 36005000100 Census Tra…                6661                 0               0
#  2 36005000200 Census Tra…                4453              1392              95
#  3 36005000400 Census Tra…                6000              2199              58
#  4 36005001600 Census Tra…                6038              2187               0
#  5 36005001901 Census Tra…                2168               885              46
#  6 36005001902 Census Tra…                1399               376              20
#  7 36005001903 Census Tra…                   0                 0               0
#  8 36005001904 Census Tra…                   0                 0               0
#  9 36005002001 Census Tra…                4694              1759               4
# 10 36005002002 Census Tra…                4274              1904              46
# # ℹ 2,317 more rows
# # ℹ 11 more variables: owner_occupied_estimate <dbl>,
# #   renter_occupied_estimate <dbl>, owner_income_estimate <dbl>,
# #   renter_income_estimate <dbl>, population_moe <dbl>, occupied_moe <dbl>,
# #   vacant_moe <dbl>, owner_occupied_moe <dbl>, renter_occupied_moe <dbl>,
# #   owner_income_moe <dbl>, renter_income_moe <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R -o nyc_census_data
# nyc_census_data
# Out:
# # A tibble: 2,327 × 16
#    GEOID       NAME        population_estimate occupied_estimate vacant_estimate
#    <chr>       <chr>                     <dbl>             <dbl>           <dbl>
#  1 36005000100 Census Tra…                6661                 0               0
#  2 36005000200 Census Tra…                4453              1392              95
#  3 36005000400 Census Tra…                6000              2199              58
#  4 36005001600 Census Tra…                6038              2187               0
#  5 36005001901 Census Tra…                2168               885              46
#  6 36005001902 Census Tra…                1399               376              20
#  7 36005001903 Census Tra…                   0                 0               0
#  8 36005001904 Census Tra…                   0                 0               0
#  9 36005002001 Census Tra…                4694              1759               4
# 10 36005002002 Census Tra…                4274              1904              46
# # ℹ 2,317 more rows
# # ℹ 11 more variables: owner_occupied_estimate <dbl>,
# #   renter_occupied_estimate <dbl>, owner_income_estimate <dbl>,
# #   renter_income_estimate <dbl>, population_moe <dbl>, occupied_moe <dbl>,
# #   vacant_moe <dbl>, owner_occupied_moe <dbl>, renter_occupied_moe <dbl>,
# #   owner_income_moe <dbl>, renter_income_moe <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %%
# %%R
# sheds_by_census_tract <- read.csv('sheds_by_census_tract.csv')

# %%
sheds_by_census_tract.to_csv('sheds_by_census_tract.csv', index=False)

# %%
# %%R
# merged_data <- read.csv("merged_data.csv")

# %%
# %%R
# sheds_by_census_tract$GEOID <- as.character(sheds_by_census_tract$GEOID)
# merged_data$GEOID <- as.character(merged_data$GEOID)

# %%
# %%R
# # Merge the data:
# library(dplyr)
#
# merged_data_new <- left_join(sheds_by_census_tract, merged_data, by = "GEOID")
# merged_data_new
# Out:
#            GEOID active_shed_licenses   Job.Number Borough.Name Count.Permits
# 1    36005000400                    1 X01112467-I1        Bronx            NA
# 2    36005001600                    3 X00974554-I1        Bronx            NA
# 3    36005001600                    3 X00974555-I1        Bronx            NA
# 4    36005001600                    3 X00974557-I1        Bronx            NA
# 5    36005001901                    3 X00002036-I1        Bronx            NA
# 6    36005001901                    3 X00677889-I1        Bronx            NA
# 7    36005001901                    3 X01059624-I1        Bronx            NA
# 8    36005001902                    8 X00372376-I1        Bronx            NA
# 9    36005001902                    8 X00763478-I1        Bronx            NA
# 10   36005001902                    8 X01013799-I1        Bronx            NA
# 11   36005001902                    8 X01057734-I1        Bronx            NA
# 12   36005001902                    8 X01082169-I1        Bronx            NA
# 13   36005001902                    8 X01140314-I1        Bronx            NA
# 14   36005001902                    8 X01166927-I1        Bronx            NA
# 15   36005001902                    8 X08026975-I1        Bronx            NA
# 16   36005001903                    1 X01128456-I1        Bronx            NA
# 17   36005002001                    2 X01056613-I1        Bronx            NA
# 18   36005002001                    2 X01088736-I1        Bronx            NA
# 19   36005002002                    3 X00829571-I1        Bronx            NA
# 20   36005002002                    3 X01088772-I1        Bronx            NA
# 21   36005002002                    3 X01179460-I1        Bronx            NA
# 22   36005002300                   10 X00321142-I1        Bronx            NA
# 23   36005002300                   10 X00321177-I1        Bronx            NA
# 24   36005002300                   10 X00369751-I1        Bronx            NA
# 25   36005002300                   10 X00369764-I1        Bronx            NA
# 26   36005002300                   10 X00410096-I1        Bronx            NA
# 27   36005002300                   10 X00410232-I1        Bronx            NA
# 28   36005002300                   10 X00410312-I1        Bronx            NA
# 29   36005002300                   10 X00410319-I1        Bronx            NA
# 30   36005002300                   10 X00410325-I1        Bronx            NA
# 31   36005002300                   10 X01165312-I1        Bronx            NA
# 32   36005002500                    6 X01090834-I1        Bronx            NA
# 33   36005002500                    6 X01091165-I1        Bronx            NA
# 34   36005002500                    6 X01091203-I1        Bronx            NA
# 35   36005002500                    6 X07999828-I1        Bronx            NA
# 36   36005002500                    6 X08055153-I1        Bronx            NA
# 37   36005002500                    6 X08055192-I1        Bronx            NA
# 38   36005002701                    8 X01091227-I1        Bronx            NA
# 39   36005002701                    8 X01091244-I1        Bronx            NA
# 40   36005002701                    8 X01140261-I1        Bronx            NA
# 41   36005002701                    8 X08055210-I1        Bronx            NA
# 42   36005002701                    8 X08055213-I1        Bronx            NA
# 43   36005002701                    8 X08055216-I1        Bronx            NA
# 44   36005002701                    8 X08055219-I1        Bronx            NA
# 45   36005002701                    8 X08055222-I1        Bronx            NA
# 46   36005002702                    5 X00851656-I1        Bronx            NA
# 47   36005002702                    5 X00898980-I1        Bronx            NA
# 48   36005002702                    5 X01008495-I1        Bronx            NA
# 49   36005002702                    5 X01063801-I1        Bronx            NA
# 50   36005002702                    5 X01159786-I1        Bronx            NA
# 51   36005002800                    5 X00909399-I1        Bronx            NA
# 52   36005002800                    5 X01110392-I1        Bronx            NA
# 53   36005002800                    5 X01110411-I1        Bronx            NA
# 54   36005002800                    5 X01110433-I1        Bronx            NA
# 55   36005002800                    5 X01110436-I1        Bronx            NA
# 56   36005003100                    4 X00900173-I1        Bronx            NA
# 57   36005003100                    4 X01197190-I1        Bronx            NA
# 58   36005003100                    4 X01208295-I1        Bronx            NA
# 59   36005003100                    4 X01208328-I1        Bronx            NA
# 60   36005003300                   11 X00685629-I1        Bronx            NA
# 61   36005003300                   11 X00984230-I1        Bronx            NA
# 62   36005003300                   11 X01050736-I1        Bronx            NA
# 63   36005003300                   11 X01052224-I1        Bronx            NA
# 64   36005003300                   11 X01052671-I1        Bronx            NA
# 65   36005003300                   11 X01056332-I1        Bronx            NA
# 66   36005003300                   11 X01063800-I1        Bronx            NA
# 67   36005003300                   11 X01124979-I1        Bronx            NA
# 68   36005003300                   11 X01159782-I1        Bronx            NA
# 69   36005003300                   11 X01159784-I1        Bronx            NA
# 70   36005003300                   11 X01180981-I1        Bronx            NA
# 71   36005003500                    4 X01013221-I1        Bronx            NA
# 72   36005003500                    4 X01013234-I1        Bronx            NA
# 73   36005003500                    4 X01062661-I1        Bronx            NA
# 74   36005003500                    4 X01148936-I1        Bronx            NA
# 75   36005003700                    1 X01142260-I1        Bronx            NA
# 76   36005003800                    3 X01079144-I1        Bronx            NA
# 77   36005003800                    3 X01088789-I1        Bronx            NA
# 78   36005003800                    3 X01088796-I1        Bronx            NA
# 79   36005003900                    8 X00320773-I1        Bronx            NA
# 80   36005003900                    8 X00909784-I1        Bronx            NA
# 81   36005003900                    8 X01003714-I1        Bronx            NA
# 82   36005003900                    8 X01062435-I1        Bronx            NA
# 83   36005003900                    8 X01090488-I1        Bronx            NA
# 84   36005003900                    8 X01132815-I1        Bronx            NA
# 85   36005003900                    8 X01202605-I1        Bronx            NA
# 86   36005003900                    8 X08012161-I1        Bronx            NA
# 87   36005004001                    1 X01099636-I1        Bronx            NA
# 88   36005004100                    8 X00320807-I1        Bronx            NA
# 89   36005004100                    8 X00320832-I1        Bronx            NA
# 90   36005004100                    8 X00320859-I1        Bronx            NA
# 91   36005004100                    8 X00320912-I1        Bronx            NA
# 92   36005004100                    8 X00320935-I1        Bronx            NA
# 93   36005004100                    8 X00320948-I1        Bronx            NA
# 94   36005004100                    8 X01084127-I1        Bronx            NA
# 95   36005004100                    8 X01199911-I1        Bronx            NA
# 96   36005004200                    3 X00769363-I1        Bronx            NA
# 97   36005004200                    3 X00989964-I1        Bronx            NA
# 98   36005004200                    3 X00989989-I1        Bronx            NA
# 99   36005004300                    5 X00371522-I1        Bronx            NA
# 100  36005004300                    5 X00796692-I1        Bronx            NA
# 101  36005004300                    5 X00894386-I1        Bronx            NA
# 102  36005004300                    5 X01003589-I1        Bronx            NA
# 103  36005004300                    5 X01146527-I1        Bronx            NA
# 104  36005004400                   19 X00277683-I1        Bronx            NA
# 105  36005004400                   19 X00277686-I1        Bronx            NA
# 106  36005004400                   19 X00277691-I1        Bronx            NA
# 107  36005004400                   19 X00295250-I1        Bronx            NA
# 163  36005005300                    7 X01119974-I1        Bronx            NA
# 164  36005005300                    7 X01119981-I1        Bronx            NA
# 165  36005005400                    6 X00792500-I1        Bronx            NA
# 166  36005005400                    6 X00975571-I1        Bronx            NA
# 167  36005005400                    6 X01014665-I1        Bronx            NA
# 168  36005005400                    6 X01029144-I1        Bronx            NA
# 169  36005005400                    6 X01166006-I1        Bronx            NA
# 170  36005005400                    6 X01208894-I1        Bronx            NA
# 171  36005005600                    3 X00896500-I1        Bronx            NA
# 172  36005005600                    3 X00970897-I1        Bronx            NA
# 173  36005005600                    3 X01092003-I1        Bronx            NA
# 174  36005005902                    7 X00064557-I1        Bronx            NA
# 175  36005005902                    7 X01037291-I1        Bronx            NA
# 176  36005005902                    7 X01043306-I1        Bronx            NA
# 177  36005005902                    7 X01054231-I1        Bronx            NA
# 178  36005005902                    7 X01128605-I1        Bronx            NA
# 179  36005005902                    7 X01136972-I1        Bronx            NA
# 180  36005005902                    7 X01144953-I1        Bronx            NA
# 181  36005006000                    2 X00579182-I1        Bronx            NA
# 182  36005006000                    2 X01166232-I1        Bronx            NA
# 183  36005006100                    1 X01019572-I1        Bronx            NA
# 184  36005006200                    1 X00939867-I1        Bronx            NA
# 185  36005006301                   19 X00128852-I1        Bronx            NA
# 186  36005006301                   19 X00166329-I1        Bronx            NA
# 187  36005006301                   19 X00342333-I1        Bronx            NA
# 188  36005006301                   19 X00533582-I1        Bronx            NA
# 189  36005006301                   19 X00542776-I1        Bronx            NA
# 190  36005006301                   19 X00742384-I1        Bronx            NA
# 191  36005006301                   19 X00802908-I1        Bronx            NA
# 192  36005006301                   19 X00988760-I1        Bronx            NA
# 193  36005006301                   19 X01021095-I1        Bronx            NA
# 194  36005006301                   19 X01030348-I1        Bronx            NA
# 195  36005006301                   19 X01038370-I1        Bronx            NA
# 196  36005006301                   19 X01041746-I1        Bronx            NA
# 197  36005006301                   19 X01042557-I1        Bronx            NA
# 198  36005006301                   19 X01072920-I1        Bronx            NA
# 199  36005006301                   19 X01080499-I1        Bronx            NA
# 200  36005006301                   19 X01098203-I1        Bronx            NA
# 201  36005006301                   19 X01099583-I1        Bronx            NA
# 202  36005006301                   19 X01126368-I1        Bronx            NA
# 203  36005006301                   19 X01166830-I1        Bronx            NA
# 204  36005006302                    1 X00296380-I1        Bronx            NA
# 205  36005006400                    1 X01168441-I1        Bronx            NA
# 206  36005006500                    6 X00888895-I1        Bronx            NA
# 207  36005006500                    6 X00985259-I1        Bronx            NA
# 208  36005006500                    6 X01004381-I1        Bronx            NA
# 209  36005006500                    6 X01064382-I1        Bronx            NA
# 210  36005006500                    6 X01138830-I1        Bronx            NA
# 211  36005006500                    6 X01190068-I1        Bronx            NA
# 212  36005006700                   10 X01045555-I1        Bronx            NA
# 213  36005006700                   10 X01051991-I1        Bronx            NA
# 214  36005006700                   10 X01091888-I1        Bronx            NA
# 215  36005006700                   10 X01116733-I1        Bronx            NA
# 216  36005006700                   10 X01186258-I1        Bronx            NA
# 217  36005006700                   10 X01193949-I1        Bronx            NA
# 1992             80197
# 1993             34872
# 1994             34872
# 1995             34872
# 1996             34872
# 1997             34872
# 1998             44618
# 1999             46371
# 2000                NA
# 2001                NA
# 2002             17534
# 2003             41925
# 2004             41925
# 2005             41925
# 2006             41925
# 2007             41925
# 2008              7254
# 2009             38784
# 2010             38784
# 2011             38784
# 2012             38784
# 2013             38784
# 2014             15779
# 2015             15779
# 2016             15779
# 2017             15779
# 2018             15779
# 2019             15779
# 2020             15779
# 2021              6739
# 2022              6739
# 2023              6739
# 2024              6739
# 2025              6739
# 2026              6739
# 2027              6739
# 2028              6739
# 2029              6739
# 2030             48652
# 2031             48652
# 2032             39653
# 2033             39653
# 2034             31800
# 2035             31800
# 2036             31800
# 2037             31800
# 2038             31800
# 2039             31800
# 2040             31800
# 2041             31800
# 2042             20427
# 2043             19115
# 2044             19115
# 2045             19115
# 2046             19115
# 2047             19115
# 2048             42531
# 2049             32817
# 2050             47032
# 2051             47032
# 2052             47032
# 2053              6388
# 2054              6388
# 2055              9134
# 2056              9134
# 2057              9134
# 2058              9134
# 2059              9134
# 2060             16795
# 2061             16795
# 2062             16795
# 2063             16795
# 2064             16795
# 2065             16795
# 2066             15489
# 2067             15489
# 2068             15489
# 2069             15489
# 2070             15489
# 2071             15489
# 2072             15489
# 2073             24516
# 2074             24516
# 2075             24516
# 2076             24516
# 2077             24516
# 2078             24516
# 2079             24516
# 2080             32699
# 2081             54925
# 2082             54925
# 2083             54925
# 2084             54925
# 2085             54925
# 2086             54925
# 2087             54925
# 2088             24839
# 2089             16880
# 2090             16880
# 2091             16880
# 2092             16880
# 2093             16880
# 2094             16880
# 2095             16880
# 2096             16880
# 2097             13560
# 2098             21828
# 2099             21828
# 2100             21828
# 2101             21828
# 2102             28388
# 2103             46335
# 2104             46335
# 2105             46335
# 2106             46335
# 2107             46335
# 2108              3703
# 2109              3703
# 2110             14586
# 2111             14586
# 2112             14586
# 2113             14586
# 2114             14586
# 2115             14586
# 2116             14586
# 2117             14586
# 2118             14586
# 2119             14586
# 2120             28570
# 2121             28570
# 2122             47014
# 2123             47014
# 2124             47014
# 2125
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### Summary statistics
#
# Pick a column or set of columns and calculate some summary statistics (like mean,median,min,max,sd).
# Hint, you may want to use `group_by` and `summarize`.

# %%
# %%R
# write.csv(merged_data_new, "merged_data_new.csv", row.names = FALSE)

# %%
# %%R
# merged_data_new <- read.csv('merged_data_new.csv')

# %%
# %%R
#
# # Stat Summary of 3 Continuous Variable:
# continuous_variables <- c('active_shed_licenses', 'Age..in.years.', 'Sidewalk.Shed.Linear.Feet')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     group_by(Borough.Name) %>% # Group by Borough
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
# # A tibble: 5 × 16
#   Borough.Name  active_shed_licenses_mean active_shed_licenses_median
#   <chr>                             <dbl>                       <dbl>
# 1 Bronx                              8.78                           7
# 2 Brooklyn                           6.82                           6
# 3 Manhattan                         18.6                           18
# 4 Queens                             6.13                           5
# 5 Staten Island                      4.25                           3
# # ℹ 13 more variables: active_shed_licenses_sd <dbl>,
# #   active_shed_licenses_mini <int>, active_shed_licenses_maxi <int>,
# #   Age..in.years._mean <dbl>, Age..in.years._median <dbl>,
# #   Age..in.years._sd <dbl>, Age..in.years._mini <dbl>,
# #   Age..in.years._maxi <dbl>, Sidewalk.Shed.Linear.Feet_mean <dbl>,
# #   Sidewalk.Shed.Linear.Feet_median <dbl>, Sidewalk.Shed.Linear.Feet_sd <dbl>,
# #   Sidewalk.Shed.Linear.Feet_mini <dbl>, …

# %%
# %%R
#
# # In General —— Stat Summary of Active Shed Counts (per census tract):
# continuous_variables <- c('active_shed_licenses')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
#   active_shed_licenses_mean active_shed_licenses_median active_shed_licenses_sd
# 1                  12.37955                           9                9.641098
#   active_shed_licenses_mini active_shed_licenses_maxi
# 1                         1                        48

# %%
# %%R
#
# # By Borough —— Stat Summary of Active Shed Counts (per census tract):
# continuous_variables <- c('active_shed_licenses')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     group_by(Borough.Name) %>% # Group by Borough
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
# # A tibble: 5 × 6
#   Borough.Name  active_shed_licenses_mean active_shed_licenses_median
#   <chr>                             <dbl>                       <dbl>
# 1 Bronx                              8.78                           7
# 2 Brooklyn                           6.82                           6
# 3 Manhattan                         18.6                           18
# 4 Queens                             6.13                           5
# 5 Staten Island                      4.25                           3
# # ℹ 3 more variables: active_shed_licenses_sd <dbl>,
# #   active_shed_licenses_mini <int>, active_shed_licenses_maxi <int>

# %%
# %%R
#
# # Stat Summary of Permit Age (in years):
# continuous_variables <- c('Age..in.years.')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     group_by(Borough.Name) %>% # Group by Borough
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
# # A tibble: 5 × 6
#   Borough.Name  Age..in.years._mean Age..in.years._median Age..in.years._sd
#   <chr>                       <dbl>                 <dbl>             <dbl>
# 1 Bronx                        1.46                 0.942              1.54
# 2 Brooklyn                     1.24                 0.759              1.46
# 3 Manhattan                    1.50                 0.962              1.60
# 4 Queens                       1.29                 0.849              1.29
# 5 Staten Island                1.45                 0.792              1.68
# # ℹ 2 more variables: Age..in.years._mini <dbl>, Age..in.years._maxi <dbl>

# %%
# %%R
#
# # Stat Summary of Permit Age (in years):
# continuous_variables <- c('Age..in.years.')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     #group_by(Borough.Name) %>% # Group by Borough
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
#   Age..in.years._mean Age..in.years._median Age..in.years._sd
# 1            1.402792             0.8863014          1.524707
#   Age..in.years._mini Age..in.years._maxi
# 1                   0            14.94247

# %%
# %%R
#
# # In General —— Stat Summary of Linear Shed Height (in feet):
# continuous_variables <- c('Sidewalk.Shed.Linear.Feet')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
#   Sidewalk.Shed.Linear.Feet_mean Sidewalk.Shed.Linear.Feet_median
# 1                       236.7404                            136.5
#   Sidewalk.Shed.Linear.Feet_sd Sidewalk.Shed.Linear.Feet_mini
# 1                     321.5308                              0
#   Sidewalk.Shed.Linear.Feet_maxi
# 1                          11325

# %%
# %%R
#
# # By Borough —— Stat Summary of Linear Shed Height (in feet):
# continuous_variables <- c('Sidewalk.Shed.Linear.Feet')
#
# summaries <- merged_data_new %>%
#     select(Borough.Name, all_of(continuous_variables)) %>%
#     group_by(Borough.Name) %>% # Group by Borough
#     summarize(across(all_of(continuous_variables),
#                      list(mean = mean,
#                           median = median,
#                           sd = sd,
#                           mini = min,
#                           maxi = max)))
# summaries
# Out:
# # A tibble: 5 × 6
#   Borough.Name  Sidewalk.Shed.Linear.Feet_mean Sidewalk.Shed.Linear.Feet_median
#   <chr>                                  <dbl>                            <dbl>
# 1 Bronx                                   290.                              205
# 2 Brooklyn                                220.                              100
# 3 Manhattan                               206.                              120
# 4 Queens                                  301.                              182
# 5 Staten Island                           350.                              220
# # ℹ 3 more variables: Sidewalk.Shed.Linear.Feet_sd <dbl>,
# #   Sidewalk.Shed.Linear.Feet_mini <dbl>, Sidewalk.Shed.Linear.Feet_maxi <dbl>

# %% [markdown]
# ### Continuous Variable 1 —— Permit Age (in years):

# %% [markdown]
# #### Histogram:

# %%
# %%R -i sheds_by_census_tract
#
# # In General —— Active Shed Count (per census tract):
#
# ggplot(merged_data_new) +
#     aes(x=active_shed_licenses)+
#     geom_histogram() +
#     labs(
#     x = 'Active Shed Count (per census tract)',
#     title = 'NYC active shed counts concentrate slightly above zero',
#     subtitle = 'Exploring the distribution of active shed counts'
#     ) +
#     theme(
#     plot.title = element_text(size = 10), # Adjust the title size
#     plot.subtitle = element_text(size = 9) # Adjust the subtitle size
#     )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R -i sheds_by_census_tract
#
# # By Borough —— Active Shed Count (per census tract):
#
# ggplot(merged_data_new) +
#     aes(x=active_shed_licenses) +
#     geom_histogram(binwidth=2) +
#     facet_wrap(~Borough.Name) +
#     labs(
#     x = 'Active Shed Count (per census tract)',
#     title = 'Manhattan outperforms other boroughs in active shed counts',
#     subtitle = 'Exploring the distribution of active shed counts across NYC boroughs'
#     ) +
#     theme(
#     plot.title = element_text(size = 10), # Adjust the title size
#     plot.subtitle = element_text(size = 9) # Adjust the subtitle size
#     )

# %% [markdown]
# #### Density plot:

# %%
# %%R -w 1000 -h 200
#
# # Permit Age (in years):
#
# ggplot(merged_data_new) +
#     aes(x=Age..in.years.,color=Borough.Name) +
#     geom_density() +
#     labs(
#     x = 'Permit Age (in years)',
#     title = 'Sidewalk active shed permits expires after approximately one year',
#     subtitle = 'Exploring the Distribution of the Poverty Rate across NYC Boroughs'
#     ) +
#     theme(
#     plot.title = element_text(size = 11), # Adjust the title size
#     plot.subtitle = element_text(size = 10) # Adjust the subtitle size
#     )

# %% [markdown]
# ### Continuous Variable 2 —— Linear Shed Height (in feet):

# %% [markdown]
# #### Histogram:

# %% [markdown]
# #### Density plot:

# %%
# %%R -w 500 -h 200
# # plot for continuous variable 1:
# # make sure to make a meaningful title and subtitle
#
# ggplot(merged_data_new) +
#     aes(x=Sidewalk.Shed.Linear.Feet, color=Borough.Name) +
#     geom_density() +
#     labs(
#     x = 'Linear Shed Height (in feet)',
#     title = 'NYC linear shed height aggregates at below 20 stories',
#     subtitle = 'Exploring the distribution of linear shed height across NYC boroughs'
#     ) +
#     theme(
#     plot.title = element_text(size = 11), # Adjust the title size
#     plot.subtitle = element_text(size = 10) # Adjust the subtitle size
#     )

# %% [markdown]
# ### Discrete Variables
#
# If there are any discrete variables you'd like to analyze, you can do that with charts here.

# %%
# There's no feasible discrete variables working for my dataset.
