# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
# merged_data_new <- read.csv("merged_data_new.csv")
# merged_data_new
# Out:
#            GEOID active_shed_licenses   Job.Number Borough.Name Count.Permits
# 1    36005000400                    1 X01112467-I1        Bronx            NA
# 2    36005001600                    3 X00974554-I1        Bronx            NA
# 3    36005001600                    3 X00974557-I1        Bronx            NA
# 4    36005001901                    3 X00002036-I1        Bronx            NA
# 5    36005001901                    3 X00677889-I1        Bronx            NA
# 6    36005001901                    3 X01059624-I1        Bronx            NA
# 7    36005001902                    8 X00372376-I1        Bronx            NA
# 8    36005001902                    8 X00763478-I1        Bronx            NA
# 9    36005001902                    8 X01013799-I1        Bronx            NA
# 10   36005001902                    8 X01057734-I1        Bronx            NA
# 11   36005001902                    8 X01082169-I1        Bronx            NA
# ...

# %% [markdown]
# #### Single Variable Regressions:

# %%
# %%R
#
# # Population estimate:
# single1 <- lm(active_shed_licenses~population_estimate, data=merged_data_new)
# summary(single1)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ population_estimate, data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -22.132  -6.379  -2.682   5.285  32.935
#
# Coefficients:
#                      Estimate Std. Error t value Pr(>|t|)
# (Intercept)         5.556e+00  2.243e-01   24.77   <2e-16 ***
# population_estimate 1.330e-03  3.954e-05   33.63   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.043 on 8456 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.1179,	Adjusted R-squared:  0.1178
# F-statistic:  1131 on 1 and 8456 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Population estimate:
# merged_data_new %>%
#   ggplot(aes(population_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "More Populated tracts keep more active sheds", x = "Population Estimate", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Occupied Population Estimate:
# single2 <- lm(active_shed_licenses~occupied_estimate, data=merged_data_new)
# summary(single2)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ occupied_estimate, data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.064  -5.709  -2.495   4.270  32.559
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)       4.432e+00  1.913e-01   23.17   <2e-16 ***
# occupied_estimate 3.624e-03  7.661e-05   47.30   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.562 on 8456 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.2092,	Adjusted R-squared:  0.2091
# F-statistic:  2237 on 1 and 8456 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Occupant Population Estimate:
# merged_data_new %>%
#   ggplot(aes(occupied_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "Tracts with more occupancy have more active sheds undergoing", x = "Occupancy Estimate", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Vacant Population Estimate:
# single3 <- lm(active_shed_licenses~vacant_estimate, data=merged_data_new)
# summary(single3)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ vacant_estimate, data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -26.649  -5.331  -1.671   3.917  36.809
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)     7.6792122  0.1138813   67.43   <2e-16 ***
# vacant_estimate 0.0136631  0.0002175   62.82   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.95 on 8456 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.3182,	Adjusted R-squared:  0.3181
# F-statistic:  3946 on 1 and 8456 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Vacant Population Estimate:
# merged_data_new %>%
#   ggplot(aes(vacant_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "More active sheds remain in vacant tracts", x = "Vacancy Estimate", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Owner-occupied Housing Unit:
# single4 <- lm(active_shed_licenses~owner_occupied_estimate, data=merged_data_new)
# summary(single4)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ owner_occupied_estimate,
#     data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -23.008  -6.225  -1.665   4.645  38.954
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)             8.6649624  0.1364324   63.51   <2e-16 ***
# owner_occupied_estimate 0.0064521  0.0001691   38.15   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.893 on 8456 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.1468,	Adjusted R-squared:  0.1467
# F-statistic:  1455 on 1 and 8456 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Owner-occupied Housing Unit:
# merged_data_new %>%
#   ggplot(aes(owner_occupied_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "Greater owner-occupied housing units turn out with more active sheds", x = "Owner-occupied Housing Unit", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Renter-occupied Housing Unit:
# single5 <- lm(active_shed_licenses~renter_occupied_estimate, data=merged_data_new)
# summary(single5)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ renter_occupied_estimate,
#     data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.533  -6.328  -3.042   4.618  33.793
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              6.8852163  0.1893720   36.36   <2e-16 ***
# renter_occupied_estimate 0.0033811  0.0001004   33.68   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.041 on 8456 degrees of freedom
#   (5 observations deleted due to missingness)
# Multiple R-squared:  0.1183,	Adjusted R-squared:  0.1182
# F-statistic:  1134 on 1 and 8456 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Renter-occupied Housing Unit:
# merged_data_new %>%
#   ggplot(aes(renter_occupied_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "More active sheds lives in tracts with greater renter-occupied housing units", x = "Renter-occupied Housing Unit", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Median Owner-occupied Income Estimate:
# single6 <- lm(active_shed_licenses~owner_income_estimate, data=merged_data_new)
# summary(single6)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ owner_income_estimate, data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.412  -5.614  -1.121   4.601  28.160
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           3.009e-01  2.685e-01    1.12    0.263
# owner_income_estimate 8.045e-05  1.629e-06   49.40   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.192 on 6508 degrees of freedom
#   (1953 observations deleted due to missingness)
# Multiple R-squared:  0.2727,	Adjusted R-squared:  0.2726
# F-statistic:  2440 on 1 and 6508 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Median Owner-occupied Income Estimate:
# merged_data_new %>%
#   ggplot(aes(owner_income_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "More active sheds remain in tracts with higher owner-occupied income", x = "Median Owner-occupied Income Estimate", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %%
# %%R
#
# # Median Renter-occupied Income Estimate:
# single7 <- lm(active_shed_licenses~renter_income_estimate, data=merged_data_new)
# summary(single7)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ renter_income_estimate, data = merged_data_new)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.804  -6.395  -1.771   4.708  39.105
#
# Coefficients:
#                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)            6.245e+00  1.815e-01   34.41   <2e-16 ***
# renter_income_estimate 7.360e-05  1.884e-06   39.07   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.672 on 8120 degrees of freedom
#   (341 observations deleted due to missingness)
# Multiple R-squared:  0.1582,	Adjusted R-squared:  0.1581
# F-statistic:  1526 on 1 and 8120 DF,  p-value: < 2.2e-16

# %%
# %%R
#
# # Median Renter-occupied Income Estimate:
# merged_data_new %>%
#   ggplot(aes(renter_income_estimate, active_shed_licenses)) +
#   geom_point() +
#   geom_smooth(method = "lm") +
#   labs(title = "More active sheds come in renter-occupied households earning a higher income", x = "Median Renter-occupied Income Estimate", y = "Active Shed Count")
# Out:
# `geom_smooth()` using formula = 'y ~ x'

# %% [markdown]
# #### Multivariable Regressions:

# %%
# %%R
#
# # All 6 variables:
# multi1 <- lm(active_shed_licenses ~ population_estimate + black_african_estimate + vacant_estimate +
#              + owner_occupied_estimate + renter_occupied_estimate +
#              + owner_income_estimate + renter_income_estimate
#              , data=merged_data_new)
# summary(multi1)
# Out:
# Call:
# lm(formula = active_shed_licenses ~ population_estimate + black_african_estimate +
#     vacant_estimate + +owner_occupied_estimate + renter_occupied_estimate +
#     +owner_income_estimate + renter_income_estimate, data = merged_data_new)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -21.9660  -3.9219  -0.6711   3.4250  23.9714
#
# Coefficients:
#                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)              -4.109e+00  3.049e-01 -13.477  < 2e-16 ***
# population_estimate       2.330e-04  8.938e-05   2.607  0.00916 **
# black_african_estimate    3.808e-04  8.849e-05   4.303 1.71e-05 ***
# vacant_estimate           7.217e-03  2.932e-04  24.616  < 2e-16 ***
# owner_occupied_estimate   1.011e-03  2.538e-04   3.983 6.88e-05 ***
# renter_occupied_estimate  1.198e-03  1.988e-04   6.029 1.74e-09 ***
# owner_income_estimate     3.822e-05  1.648e-06  23.192  < 2e-16 ***
# ...

# %%
# %%R
#
# # See the columns
# colnames(merged_data_new)
# Out:
#  [1] "GEOID"                     "active_shed_licenses"
#  [3] "Job.Number"                "Borough.Name"
#  [5] "Count.Permits"             "First.Permit.Date"
#  [7] "Current.Date"              "Age..in.years."
#  [9] "Permit.Expiration.Date"    "Sidewalk.Shed.Linear.Feet"
# [11] "Construction.Material"     "Current.Job.Status"
# [13] "BIN.Number"                "Community.Board"
# [15] "Latitude.Point"            "Longitude.Point"
# [17] "House.Number"              "Street.Name"
# [19] "Borough.Digit"             "Block"
# [21] "Lot"                       "Applicant.Business.Name"
# [23] "ProCert"                   "Source"
# [25] "activity"                  "Commercial"
# [27] "STATE"                     "COUNTY"
# [29] "TRACT"                     "BLOCK"
# [31] "NAME"                      "population_estimate"
# [33] "black_african_estimate"    "occupied_estimate"
# [35] "vacant_estimate"           "owner_occupied_estimate"
# ...

# %%
# %%R
#
# ggplot(merged_data_new) +
#     aes(x=occupied_estimate/population_estimate, y=vacant_estimate/population_estimate) +
#     geom_point()
